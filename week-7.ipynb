# %% [markdown]
# # Python Performance Tuning and Optimization
# ## Key Areas of Optimization
# - Algorithmic Optimization
# - Data Structure Selection
# - Code Profiling and Analysis
# - Memory Management
# - Concurrency and Parallelism
# - Using Built-in Libraries

# %% [markdown]
# ### Algorithmic Optimization
# - Algorithmic optimization is the process of improving the efficiency of algorithms
# - Algorithmic optimization is used to reduce both the time complexity (execution time) or space complexity (memory usage())

# %% [markdown]
# ### Memoization/dynamic programming Example

# %%
# define a Fibonacci Function
def fib_recursive(n): # time complexity(O(2^n))
    if n <= 1:
        return n
    return fib_recursive(n-1) + fib_recursive(n-2)

fib_10  =fib_recursive(10)# we can't use this function to get the large number's fib number
print(fib_10)  

# Initialize the memoization dictionary with base cases
memo = {0: 0, 1: 1} 
def fib_memo(n): # time complexity O(n)
    # Check if the result for 'n' is already in the memo dictionary
    if n in memo:
        return memo[n]
    
    # Recursive case: calculate Fibonacci number for n
    fib_number = fib_memo(n-1) + fib_memo(n-2)
    
    # Store the result in the memo dictionary to avoid redundant calculations
    memo[n] = fib_number
    
    return fib_number


print(fib_memo(100))
# Out:
# 55
# 354224848179261915075

# %% [markdown]
# ### Use Dict/Set (Hashmaps) to optimize the search

# %%
# Linear Search
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return True
    return False

arr = [5, 2, 9, 1, 5, 6]
print(linear_search(arr, 5))  # Check that 5 is in give array or not O(n)

# Use Set to optimize the search O(1)
def optimized_search(arr, target):
    hash_set = set(arr)  
    return target in hash_set

arr = [5, 2, 9, 1, 5, 6]
print(optimized_search(arr, 5))  # (O(1) average
# Out:
# True
# True

# %% [markdown]
# ### Data Structure Selection

# %%
from collections import deque
#### Queue Implementation 
# Without optimization: Using list (O(n) for dequeuing)
queue = [1, 2, 3]
queue.append(4)  # Enqueue (O(1))
queue.pop(0)  # Dequeue (O(n))

# Optimized: Using deque (O(1))
queue_deque = deque([1, 2, 3])
queue_deque.append(4)  # Enqueue (O(1))
queue_deque.popleft()  # Dequeue (O(1))
# Out:
# True
# True
# 1

# %% [markdown]
# #### Home Work
# - Searching for Elements in a Collection (Use Dict)
#     - Write a function so that from a given list of length n, if an element exists on the list return True, else False
# -  Queue-based Problems
#     - FIFO and LIFO ( use ``deque`` from the ``collection``)
#         - Task:  Simulate FIFO and LIFO Queue with  list and with deque and profile the time complexity

# %% [markdown]
# ## Code Profiling and Analysis

# %% [markdown]
# #### Command Line Profiling:

# %%
# !python -m cProfile main.py
# Out:
# 0.7071067811865475
# Error: (2003, "Can't connect to MySQL server on '127.0.0.1' ([WinError 10061] No connection could be made because the target machine actively refused it)")
#          58511 function calls (57199 primitive calls) in 2.121 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      73/1    0.001    0.000    2.121    2.121 {built-in method builtins.exec}
#         1    0.000    0.000    2.121    2.121 main.py:1(<module>)
#         1    0.000    0.000    2.045    2.045 database.py:4(__init__)
#         1    0.000    0.000    2.045    2.045 connections.py:168(__init__)
#         1    0.000    0.000    2.045    2.045 connections.py:631(connect)
#         1    0.000    0.000    2.037    2.037 socket.py:811(create_connection)
#         1    2.034    2.034    2.034    2.034 {method 'connect' of '_socket.socket' objects}
#        14    0.000    0.000    0.101    0.007 __init__.py:1(<module>)
#      86/5    0.001    0.000    0.077    0.015 <frozen importlib._bootstrap>:1349(_find_and_load)
#      86/5    0.000    0.000    0.077    0.015 <frozen importlib._bootstrap>:1304(_find_and_load_unlocked)
#      85/7    0.000    0.000    0.076    0.011 <frozen importlib._bootstrap>:911(_load_unlocked)
#      68/6    0.000    0.000    0.076    0.013 <frozen importlib._bootstrap_external>:989(exec_module)
#    205/12    0.000    0.000    0.072    0.006 <frozen importlib._bootstrap>:480(_call_with_frames_removed)
#         1    0.000    0.000    0.066    0.066 database.py:1(<module>)
#      27/6    0.000    0.000    0.063    0.011 {built-in method builtins.__import__}
#      44/4    0.000    0.000    0.060    0.015 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.057    0.057 connections.py:1(<module>)
#         1    0.000    0.000    0.030    0.030 _auth.py:1(<module>)
#        68    0.001    0.000    0.023    0.000 <frozen importlib._bootstrap_external>:1062(get_code)
#        86    0.001    0.000    0.020    0.000 <frozen importlib._bootstrap>:1240(_find_spec)
#        78    0.000    0.000    0.019    0.000 <frozen importlib._bootstrap_external>:1520(find_spec)
#        78    0.000    0.000    0.019    0.000 <frozen importlib._bootstrap_external>:1491(_get_spec)
#       171    0.001    0.000    0.017    0.000 <frozen importlib._bootstrap_external>:1593(find_spec)
#         1    0.000    0.000    0.015    0.015 ssh.py:1(<module>)
#        68    0.000    0.000    0.014    0.000 <frozen importlib._bootstrap_external>:1183(get_data)
#       376    0.014    0.000    0.014    0.000 {built-in method nt.stat}
#       374    0.000    0.000    0.014    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#     85/83    0.000    0.000    0.012    0.000 <frozen importlib._bootstrap>:806(module_from_spec)
#       9/8    0.000    0.000    0.009    0.001 <frozen importlib._bootstrap_external>:1287(create_module)
#       9/8    0.007    0.001    0.009    0.001 {built-in method _imp.create_dynamic}
#        68    0.008    0.000    0.008    0.000 {method 'read' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.008    0.008 _serialization.py:1(<module>)
#         1    0.000    0.000    0.008    0.008 traceback.py:182(format_exc)
#         1    0.000    0.000    0.008    0.008 traceback.py:128(format_exception)
#       255    0.002    0.000    0.008    0.000 {built-in method builtins.__build_class__}
#         1    0.000    0.000    0.007    0.007 traceback.py:718(__init__)
#         1    0.000    0.000    0.007    0.007 traceback.py:399(_extract_from_extended_frame_gen)
#        18    0.000    0.000    0.007    0.000 traceback.py:318(line)
#         3    0.000    0.000    0.007    0.002 linecache.py:26(getline)
#         3    0.000    0.000    0.007    0.002 linecache.py:36(getlines)
#         1    0.000    0.000    0.007    0.007 hashes.py:1(<module>)
#         2    0.000    0.000    0.007    0.003 linecache.py:80(updatecache)
#       123    0.000    0.000    0.006    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#       110    0.000    0.000    0.006    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#        20    0.000    0.000    0.005    0.000 __init__.py:226(compile)
#        20    0.000    0.000    0.005    0.000 __init__.py:280(_compile)
#       846    0.003    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#        20    0.000    0.000    0.005    0.000 _compiler.py:740(compile)
#        68    0.005    0.000    0.005    0.000 {built-in method _io.open_code}
#         1    0.000    0.000    0.005    0.005 socket.py:1(<module>)
#        68    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:751(_compile_bytecode)
#         2    0.000    0.000    0.004    0.002 tokenize.py:445(open)
#         1    0.000    0.000    0.004    0.004 ssl.py:1(<module>)
#        68    0.004    0.000    0.004    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.004    0.004 converters.py:1(<module>)
#         2    0.000    0.000    0.004    0.002 tokenize.py:352(detect_encoding)
#         4    0.000    0.000    0.003    0.001 tokenize.py:376(read_or_stop)
#         4    0.003    0.001    0.003    0.001 {method 'readline' of '_io.BufferedReader' objects}
#        20    0.000    0.000    0.003    0.000 _parser.py:969(parse)
#     78/20    0.000    0.000    0.003    0.000 _parser.py:452(_parse_sub)
#     93/21    0.001    0.000    0.003    0.000 _parser.py:512(_parse)
#         1    0.000    0.000    0.003    0.003 socket.py:947(getaddrinfo)
#        68    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:1202(path_stats)
#         1    0.000    0.000    0.003    0.003 {built-in method _socket.getaddrinfo}
#         1    0.000    0.000    0.002    0.002 __init__.py:71(search_function)
#         1    0.000    0.000    0.002    0.002 optionfile.py:1(<module>)
#        10    0.000    0.000    0.002    0.000 enum.py:919(_convert_)
#         1    0.000    0.000    0.002    0.002 decimal.py:1(<module>)
#         2    0.000    0.000    0.002    0.001 base.py:1(<module>)
#       136    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:482(cache_from_source)
#        20    0.000    0.000    0.002    0.000 _compiler.py:573(_code)
#        14    0.001    0.000    0.002    0.000 enum.py:1708(convert_class)
#        85    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap>:733(_init_module_attrs)
#         1    0.000    0.000    0.002    0.002 err.py:1(<module>)
#         2    0.002    0.001    0.002    0.001 {method 'readlines' of '_io._IOBase' objects}
#        86    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap>:416(__enter__)
#         1    0.000    0.000    0.002    0.002 idna.py:1(<module>)
#   438/412    0.001    0.000    0.002    0.000 {built-in method __new__ of type object at 0x00007FF84C927A20}
#         9    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:1295(exec_module)
#         1    0.000    0.000    0.002    0.002 configparser.py:1(<module>)
#    171/20    0.001    0.000    0.002    0.000 _compiler.py:37(_compile)
#         9    0.002    0.000    0.002    0.000 {built-in method _imp.exec_dynamic}
#       145    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap>:632(cached)
#        77    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:611(_get_cached)
#       113    0.000    0.000    0.001    0.000 <frozen abc>:105(__new__)
#       107    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:304(acquire)
#       199    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1469(_path_importer_cache)
#         1    0.000    0.000    0.001    0.001 hashlib.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 modes.py:1(<module>)
#        70    0.001    0.000    0.001    0.000 {method '__exit__' of '_io._IOBase' objects}
#        12    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1456(_path_hooks)
#         1    0.000    0.000    0.001    0.001 padding.py:1(<module>)
#        12    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1644(_fill_cache)
#         1    0.000    0.000    0.001    0.001 configparser.py:541(RawConfigParser)
#        22    0.000    0.000    0.001    0.000 enum.py:528(__new__)
#         1    0.000    0.000    0.001    0.001 ec.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 cursors.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 selectors.py:1(<module>)
#        12    0.001    0.000    0.001    0.000 {built-in method nt.listdir}
#         1    0.000    0.000    0.001    0.001 __init__.py:469(StrFormatStyle)
#         1    0.000    0.000    0.001    0.001 times.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 dataclasses.py:1247(dataclass)
#         1    0.000    0.000    0.001    0.001 dataclasses.py:1264(wrap)
#         1    0.000    0.000    0.001    0.001 dataclasses.py:921(_process_class)
#         1    0.000    0.000    0.001    0.001 string.py:1(<module>)
#        77    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1588(_get_spec)
#        57    0.001    0.000    0.001    0.000 _compiler.py:243(_optimize_charset)
#      3659    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#       107    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:162(__enter__)
#         6    0.000    0.000    0.001    0.000 traceback.py:944(format)
#        12    0.000    0.000    0.001    0.000 <frozen zipimport>:64(__init__)
#         1    0.000    0.000    0.001    0.001 getpass.py:1(<module>)
#       136    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         1    0.000    0.000    0.001    0.001 stringprep.py:1(<module>)
#       107    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:426(_get_module_lock)
#         1    0.000    0.000    0.001    0.001 string.py:69(__init_subclass__)
# 5246/5055    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#      3917    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      3028    0.001    0.000    0.001    0.000 {method 'endswith' of 'str' objects}
#        77    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:802(spec_from_file_location)
#      1718    0.000    0.000    0.001    0.000 _parser.py:261(get)
#         5    0.000    0.000    0.001    0.000 __init__.py:355(namedtuple)
#         1    0.000    0.000    0.001    0.001 six.py:1(<module>)
#        12    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1685(path_hook_for_FileFinder)
#       107    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:124(setdefault)
#         1    0.000    0.000    0.000    0.000 __init__.py:436(PercentStyle)
#         1    0.000    0.000    0.000    0.000 traceback.py:525(format)
#         6    0.000    0.000    0.000    0.000 __init__.py:1660(_log)
#         3    0.000    0.000    0.000    0.000 traceback.py:460(format_frame_summary)
#        20    0.000    0.000    0.000    0.000 _compiler.py:511(_compile_info)
#        89    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:185(_path_abspath)
#         1    0.000    0.000    0.000    0.000 dsa.py:1(<module>)
#      2681    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:164(_path_isdir)
#      2890    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#   420/416    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#        89    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:172(_path_isabs)
#        21    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:463(_lock_unlock_module)
#       166    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#      1144    0.000    0.000    0.000    0.000 _parser.py:168(__getitem__)
#       107    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:372(release)
#        86    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:420(__exit__)
#      1017    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 dataclasses.py:449(_create_fn)
#         1    0.000    0.000    0.000    0.000 algorithms.py:1(<module>)
#        86    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:232(__init__)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.eval}
#         1    0.000    0.000    0.000    0.000 numbers.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 socket.py:221(__init__)
#       113    0.000    0.000    0.000    0.000 {built-in method _abc._abc_init}
#       9/8    0.000    0.000    0.000    0.000 typing.py:392(inner)
#      1968    0.000    0.000    0.000    0.000 _parser.py:240(__next)
#    217/66    0.000    0.000    0.000    0.000 _parser.py:178(getwidth)
#        68    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:666(_classify_pyc)
#        86    0.000    0.000    0.000    0.000 __init__.py:82(find_spec)
#        24    0.000    0.000    0.000    0.000 enum.py:254(__set_name__)
#        52    0.000    0.000    0.000    0.000 enum.py:390(__setitem__)
#       243    0.000    0.000    0.000    0.000 enum.py:850(__setattr__)
#      1187    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 traceback.py:351(_walk_tb_with_full_positions)
#         2    0.000    0.000    0.000    0.000 {built-in method _io.open}
#       7/6    0.000    0.000    0.000    0.000 typing.py:515(__getitem__)
#         3    0.000    0.000    0.000    0.000 traceback.py:365(_get_code_position)
#         6    0.000    0.000    0.000    0.000 __init__.py:1686(handle)
#         6    0.000    0.000    0.000    0.000 typing.py:694(Union)
#         1    0.000    0.000    0.000    0.000 traceback.py:1(<module>)
#         6    0.000    0.000    0.000    0.000 __init__.py:1746(callHandlers)
#         2    0.000    0.000    0.000    0.000 utils.py:1(<module>)
#       204    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#        86    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:982(find_spec)
#        46    0.000    0.000    0.000    0.000 _parser.py:98(closegroup)
#       408    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#         6    0.000    0.000    0.000    0.000 __init__.py:1011(handle)
#         1    0.000    0.000    0.000    0.000 _oid.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:568(_init_fn)
#        40    0.000    0.000    0.000    0.000 enum.py:1562(__and__)
#         6    0.000    0.000    0.000    0.000 __init__.py:1148(emit)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 __init__.py:2218(debug)
#         8    0.000    0.000    0.000    0.000 traceback.py:665(emit)
#        68    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:699(_validate_timestamp_pyc)
#         1    0.000    0.000    0.000    0.000 __init__.py:1517(debug)
#         2    0.000    0.000    0.000    0.000 traceback.py:589(_extract_caret_anchors_from_line_segment)
#       107    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:74(__new__)
#        12    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1567(__init__)
#       528    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       886    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         8    0.000    0.000    0.000    0.000 enum.py:513(__prepare__)
#       221    0.000    0.000    0.000    0.000 enum.py:79(_is_private)
#        14    0.000    0.000    0.000    0.000 hashlib.py:126(__get_openssl_constructor)
#        89    0.000    0.000    0.000    0.000 {built-in method nt._path_splitroot}
#         2    0.000    0.000    0.000    0.000 ast.py:34(parse)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:989(create_module)
#         1    0.000    0.000    0.000    0.000 inspect.py:3333(signature)
#         1    0.000    0.000    0.000    0.000 inspect.py:3071(from_callable)
#       887    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:491(_verbose_message)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.000    0.000 charset.py:1(<module>)
#         8    0.000    0.000    0.000    0.000 typing.py:1260(__init__)
#       3/1    0.000    0.000    0.000    0.000 inspect.py:2491(_signature_from_callable)
#         6    0.000    0.000    0.000    0.000 __init__.py:1645(makeRecord)
#        86    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:445(cb)
#         1    0.000    0.000    0.000    0.000 datetime.py:1(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:2175(error)
#         8    0.000    0.000    0.000    0.000 {built-in method _imp.create_builtin}
#         2    0.000    0.000    0.000    0.000 __init__.py:1558(error)
#         1    0.000    0.000    0.000    0.000 configparser.py:348(BasicInterpolation)
#         6    0.000    0.000    0.000    0.000 __init__.py:298(__init__)
#       329    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1226(__exit__)
#       194    0.000    0.000    0.000    0.000 enum.py:38(_is_descriptor)
#       327    0.000    0.000    0.000    0.000 _parser.py:176(append)
#        78    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1128(find_spec)
#         1    0.000    0.000    0.000    0.000 struct.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 socket.py:501(close)
#        86    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         6    0.000    0.000    0.000    0.000 __init__.py:988(format)
#       107    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:82(remove)
#         1    0.000    0.000    0.000    0.000 configparser.py:494(LegacyInterpolation)
#       489    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 __init__.py:690(format)
#         1    0.000    0.000    0.000    0.000 socket.py:497(_real_close)
#         1    0.000    0.000    0.000    0.000 exceptions.py:1(<module>)
#        14    0.000    0.000    0.000    0.000 <frozen codecs>:319(decode)
#       225    0.000    0.000    0.000    0.000 socket.py:79(<lambda>)
#       226    0.000    0.000    0.000    0.000 socket.py:84(<lambda>)
#       329    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1222(__enter__)
#       385    0.000    0.000    0.000    0.000 _parser.py:164(__len__)
#       241    0.000    0.000    0.000    0.000 enum.py:48(_is_dunder)
#       228    0.000    0.000    0.000    0.000 socket.py:94(<lambda>)
#       906    0.000    0.000    0.000    0.000 {method 'isupper' of 'str' objects}
#       227    0.000    0.000    0.000    0.000 socket.py:89(<lambda>)
#         1    0.000    0.000    0.000    0.000 configparser.py:420(ExtendedInterpolation)
#       487    0.000    0.000    0.000    0.000 _parser.py:256(match)
#        52    0.000    0.000    0.000    0.000 enum.py:726(__call__)
#       290    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        68    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:643(_check_name_wrapper)
#         6    0.000    0.000    0.000    0.000 __init__.py:1611(findCaller)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:627(_repr_fn)
#         1    0.000    0.000    0.000    0.000 {function socket.close at 0x00000218A3875B20}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(exec_module)
#        79    0.000    0.000    0.000    0.000 _compiler.py:398(_simple)
#         1    0.000    0.000    0.000    0.000 protocol.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:661(_cmp_fn)
#         1    0.000    0.000    0.000    0.000 configparser.py:1277(ConverterMapping)
#       107    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:79(__init__)
#         8    0.000    0.000    0.000    0.000 {built-in method _imp.exec_builtin}
#        60    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 hashlib.py:82(__get_builtin_constructor)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       169    0.000    0.000    0.000    0.000 types.py:192(__init__)
#         7    0.000    0.000    0.000    0.000 dataclasses.py:760(_get_field)
#        72    0.000    0.000    0.000    0.000 _parser.py:372(_escape)
#       366    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#       107    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:645(parent)
#       171    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#       121    0.000    0.000    0.000    0.000 <frozen abc>:7(abstractmethod)
#       522    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        55    0.000    0.000    0.000    0.000 typing.py:1206(__setattr__)
#         1    0.000    0.000    0.000    0.000 __init__.py:2208(info)
#     23/15    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 traceback.py:869(format_exception_only)
#       107    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#       221    0.000    0.000    0.000    0.000 enum.py:59(_is_sunder)
#         1    0.000    0.000    0.000    0.000 __init__.py:1529(info)
#       126    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#       235    0.000    0.000    0.000    0.000 _parser.py:293(tell)
#       522    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#        68    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#        16    0.000    0.000    0.000    0.000 enum.py:967(_get_mixins_)
#     23/15    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         4    0.000    0.000    0.000    0.000 tokenize.py:382(find_cookie)
#       347    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 algorithms.py:60(Camellia)
#         1    0.000    0.000    0.000    0.000 padding.py:64(OAEP)
#        46    0.000    0.000    0.000    0.000 _parser.py:86(opengroup)
#        57    0.000    0.000    0.000    0.000 _compiler.py:216(_compile_charset)
#         1    0.000    0.000    0.000    0.000 trigonometry.py:8(sine)
#         1    0.000    0.000    0.000    0.000 numbers.py:57(Complex)
#        24    0.000    0.000    0.000    0.000 __init__.py:200(_is_internal_frame)
#        21    0.000    0.000    0.000    0.000 dataclasses.py:701(_is_type)
#         1    0.000    0.000    0.000    0.000 __init__.py:2021(basicConfig)
#        52    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#         8    0.000    0.000    0.000    0.000 _compiler.py:386(_mk_bitmap)
#         6    0.000    0.000    0.000    0.000 __init__.py:622(formatTime)
#         1    0.000    0.000    0.000    0.000 __init__.py:2193(warning)
#       214    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#        27    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        66    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        68    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         1    0.000    0.000    0.000    0.000 _cipheralgorithm.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 typing.py:747(Optional)
#         1    0.000    0.000    0.000    0.000 __init__.py:1541(warning)
#         1    0.000    0.000    0.000    0.000 rsa.py:1(<module>)
#        86    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        65    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#        14    0.000    0.000    0.000    0.000 <frozen abc>:110(register)
#        23    0.000    0.000    0.000    0.000 typing.py:175(_type_check)
#         1    0.000    0.000    0.000    0.000 inspect.py:2387(_signature_from_function)
#         1    0.000    0.000    0.000    0.000 __init__.py:2159(critical)
#         8    0.000    0.000    0.000    0.000 typing.py:1165(__init__)
#         5    0.000    0.000    0.000    0.000 textwrap.py:470(indent)
#         1    0.000    0.000    0.000    0.000 weakref.py:104(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1576(critical)
#       204    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#        16    0.000    0.000    0.000    0.000 enum.py:1008(_find_data_type_)
#         2    0.000    0.000    0.000    0.000 typing.py:1065(_generic_class_getitem)
#        14    0.000    0.000    0.000    0.000 {built-in method _abc._abc_register}
#        25    0.000    0.000    0.000    0.000 <frozen ntpath>:51(normcase)
#       137    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 ed25519.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 weakref.py:289(update)
#        27    0.000    0.000    0.000    0.000 typing.py:730(<genexpr>)
#        78    0.000    0.000    0.000    0.000 {built-in method _imp.find_frozen}
#         3    0.000    0.000    0.000    0.000 linecache.py:147(lazycache)
#     25/18    0.000    0.000    0.000    0.000 _compiler.py:436(_get_literal_prefix)
#         4    0.000    0.000    0.000    0.000 utils.py:92(deprecated)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#       132    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        30    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#         1    0.000    0.000    0.000    0.000 ssl.py:394(_ASN1Object)
#        38    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        14    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#       169    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:662(spec_from_loader)
#        88    0.000    0.000    0.000    0.000 six.py:146(__init__)
#         1    0.000    0.000    0.000    0.000 _serialization.py:21(Encoding)
#         1    0.000    0.000    0.000    0.000 _serialization.py:46(PublicFormat)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#       156    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       256    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#       121    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#       107    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         1    0.000    0.000    0.000    0.000 __future__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _serialization.py:30(PrivateFormat)
#        57    0.000    0.000    0.000    0.000 typing.py:1152(_is_dunder)
#         8    0.000    0.000    0.000    0.000 enum.py:1035(_find_new_)
#       226    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        21    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 enum.py:1414(_missing_)
#       128    0.000    0.000    0.000    0.000 ssl.py:125(<lambda>)
#         1    0.000    0.000    0.000    0.000 inspect.py:3287(__str__)
#       128    0.000    0.000    0.000    0.000 ssl.py:135(<lambda>)
#       128    0.000    0.000    0.000    0.000 ssl.py:140(<lambda>)
#         1    0.000    0.000    0.000    0.000 <frozen os>:44(_get_exports_list)
#        64    0.000    0.000    0.000    0.000 enum.py:785(__delattr__)
#       128    0.000    0.000    0.000    0.000 ssl.py:130(<lambda>)
#        10    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#       132    0.000    0.000    0.000    0.000 _parser.py:83(groups)
#       128    0.000    0.000    0.000    0.000 ssl.py:145(<lambda>)
#         6    0.000    0.000    0.000    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#       128    0.000    0.000    0.000    0.000 ssl.py:150(<lambda>)
#         6    0.000    0.000    0.000    0.000 <frozen ntpath>:268(basename)
#         4    0.000    0.000    0.000    0.000 ssl.py:399(__new__)
#         6    0.000    0.000    0.000    0.000 {built-in method time.localtime}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 _oid.py:13(ExtensionOID)
#       107    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 typing.py:345(_remove_dups_flatten)
#        14    0.000    0.000    0.000    0.000 textwrap.py:482(prefixed_lines)
#        86    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:599(__init__)
#        20    0.000    0.000    0.000    0.000 _parser.py:231(__init__)
#         6    0.000    0.000    0.000    0.000 traceback.py:573(_byte_offset_to_character_offset)
#         6    0.000    0.000    0.000    0.000 <frozen ntpath>:236(split)
#         1    0.000    0.000    0.000    0.000 ssl.py:415(Purpose)
#       173    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       185    0.000    0.000    0.000    0.000 _parser.py:113(__init__)
#        19    0.000    0.000    0.000    0.000 _parser.py:449(_uniq)
#         2    0.000    0.000    0.000    0.000 __init__.py:592(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:928(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#         1    0.000    0.000    0.000    0.000 _serialization.py:16(PBES)
#        12    0.000    0.000    0.000    0.000 _parser.py:274(getuntil)
#        98    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#       239    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         6    0.000    0.000    0.000    0.000 __init__.py:1790(isEnabledFor)
#         4    0.000    0.000    0.000    0.000 {built-in method _ssl.txt2obj}
#        83    0.000    0.000    0.000    0.000 _parser.py:172(__setitem__)
#         1    0.000    0.000    0.000    0.000 numbers.py:172(Real)
#         6    0.000    0.000    0.000    0.000 <frozen ntpath>:257(splitext)
#         4    0.000    0.000    0.000    0.000 _compiler.py:391(_bytes_to_codes)
#         1    0.000    0.000    0.000    0.000 _asymmetric.py:1(<module>)
#        20    0.000    0.000    0.000    0.000 trigonometry.py:2(factorial)
#         1    0.000    0.000    0.000    0.000 ssl.py:944(SSLSocket)
#         1    0.000    0.000    0.000    0.000 ssh.py:797(SSHCertificateType)
#         7    0.000    0.000    0.000    0.000 inspect.py:2820(__str__)
#         1    0.000    0.000    0.000    0.000 getpass.py:154(getuser)
#         9    0.000    0.000    0.000    0.000 typing.py:262(_collect_parameters)
#       143    0.000    0.000    0.000    0.000 charset.py:39(add)
#         1    0.000    0.000    0.000    0.000 base64.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 connections.py:91(Connection)
#        96    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       169    0.000    0.000    0.000    0.000 enum.py:241(__set_name__)
#         6    0.000    0.000    0.000    0.000 __init__.py:674(formatMessage)
#         6    0.000    0.000    0.000    0.000 enum.py:1404(_iter_member_by_def_)
#         2    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#        47    0.000    0.000    0.000    0.000 six.py:110(__init__)
#         8    0.000    0.000    0.000    0.000 inspect.py:2733(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.dir}
#         6    0.000    0.000    0.000    0.000 {built-in method time.strftime}
#         6    0.000    0.000    0.000    0.000 __init__.py:1137(flush)
#         1    0.000    0.000    0.000    0.000 ER.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 utils.py:126(Enum)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        54    0.000    0.000    0.000    0.000 six.py:182(_add_module)
#        52    0.000    0.000    0.000    0.000 enum.py:70(_is_internal_class)
#         4    0.000    0.000    0.000    0.000 <frozen _collections_abc>:804(get)
#         6    0.000    0.000    0.000    0.000 __init__.py:462(format)
#       191    0.000    0.000    0.000    0.000 enum.py:1185(__init__)
#        25    0.000    0.000    0.000    0.000 {built-in method _winapi.LCMapStringEx}
#         1    0.000    0.000    0.000    0.000 inspect.py:2114(_signature_bound_method)
#        86    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:412(__init__)
#         6    0.000    0.000    0.000    0.000 <frozen genericpath>:133(_splitext)
#         2    0.000    0.000    0.000    0.000 inspect.py:3019(__init__)
#         3    0.000    0.000    0.000    0.000 inspect.py:2020(_signature_get_user_defined_method)
#         1    0.000    0.000    0.000    0.000 __init__.py:1126(__init__)
#       107    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:158(__init__)
#         2    0.000    0.000    0.000    0.000 inspect.py:176(get_annotations)
#        40    0.000    0.000    0.000    0.000 _compiler.py:570(isstring)
#         6    0.000    0.000    0.000    0.000 __init__.py:455(_format)
#         1    0.000    0.000    0.000    0.000 __init__.py:1293(__init__)
#         8    0.000    0.000    0.000    0.000 enum.py:957(_check_for_existing_members_)
#         2    0.000    0.000    0.000    0.000 __init__.py:450(validate)
#        85    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:653(has_location)
#        10    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        57    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 <frozen os>:709(__getitem__)
#         2    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#        25    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.000    0.000    0.000    0.000 ssl.py:422(SSLContext)
#       143    0.000    0.000    0.000    0.000 charset.py:7(__init__)
#        96    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1573(<genexpr>)
#        12    0.000    0.000    0.000    0.000 _compiler.py:467(_get_charset_prefix)
#         8    0.000    0.000    0.000    0.000 enum.py:383(__init__)
#         1    0.000    0.000    0.000    0.000 typing.py:1114(_generic_init_subclass)
#        68    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1153(__init__)
#         1    0.000    0.000    0.000    0.000 _serialization.py:55(ParameterFormat)
#         1    0.000    0.000    0.000    0.000 trigonometry.py:19(cosine)
#        21    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 base.py:78(Cipher)
#         8    0.000    0.000    0.000    0.000 inspect.py:1457(formatannotation)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:501(_requires_builtin_wrapper)
#       100    0.000    0.000    0.000    0.000 enum.py:942(<lambda>)
#        58    0.000    0.000    0.000    0.000 _compiler.py:31(_combine_flags)
#         6    0.000    0.000    0.000    0.000 _compiler.py:407(_generate_overlap_table)
#         1    0.000    0.000    0.000    0.000 __init__.py:43(normalize_encoding)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:250(_recursive_repr)
#        25    0.000    0.000    0.000    0.000 typing.py:166(_type_convert)
#         2    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#        81    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#        46    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 _parser.py:953(fix_flags)
#       135    0.000    0.000    0.000    0.000 six.py:93(__init__)
#         3    0.000    0.000    0.000    0.000 traceback.py:265(__init__)
#         1    0.000    0.000    0.000    0.000 _oid.py:90(SignatureAlgorithmOID)
#         4    0.000    0.000    0.000    0.000 dataclasses.py:864(_set_new_attribute)
#         4    0.000    0.000    0.000    0.000 {method 'tolist' of 'memoryview' objects}
#         2    0.000    0.000    0.000    0.000 __init__.py:892(_addHandlerRef)
#         1    0.000    0.000    0.000    0.000 _oid.py:55(NameOID)
#         1    0.000    0.000    0.000    0.000 inspect.py:3087(replace)
#         1    0.000    0.000    0.000    0.000 traceback.py:856(_load_lines)
#         1    0.000    0.000    0.000    0.000 idna.py:308(getregentry)
#         1    0.000    0.000    0.000    0.000 idna.py:155(encode)
#        34    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 enum.py:1394(_iter_member_by_value_)
#         6    0.000    0.000    0.000    0.000 __init__.py:668(usesTime)
#         6    0.000    0.000    0.000    0.000 <frozen ntpath>:179(splitroot)
#         2    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:1835(getattr_static)
#         2    0.000    0.000    0.000    0.000 linecache.py:52(checkcache)
#         1    0.000    0.000    0.000    0.000 socket.py:215(socket)
#         1    0.000    0.000    0.000    0.000 __init__.py:1510(setLevel)
#         1    0.000    0.000    0.000    0.000 numbers.py:319(Integral)
#        15    0.000    0.000    0.000    0.000 ssl.py:938(_sslcopydoc)
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_md5}
#         4    0.000    0.000    0.000    0.000 typing.py:2496(overload)
#        34    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         2    0.000    0.000    0.000    0.000 traceback.py:170(_safe_string)
#        10    0.000    0.000    0.000    0.000 __init__.py:234(_acquireLock)
#        26    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#         4    0.000    0.000    0.000    0.000 <frozen os>:783(encodekey)
#         7    0.000    0.000    0.000    0.000 dataclasses.py:404(field)
#        38    0.000    0.000    0.000    0.000 enum.py:93(_is_single_bit)
#         1    0.000    0.000    0.000    0.000 ssl.py:783(SSLObject)
#         6    0.000    0.000    0.000    0.000 typing.py:317(_deduplicate)
#         2    0.000    0.000    0.000    0.000 __init__.py:958(createLock)
#        42    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#        68    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1178(get_filename)
#         6    0.000    0.000    0.000    0.000 six.py:131(__init__)
#         8    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 traceback.py:96(_parse_value_tb)
#         8    0.000    0.000    0.000    0.000 enum.py:986(_find_data_repr_)
#       128    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         5    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 __init__.py:243(_releaseLock)
#         2    0.000    0.000    0.000    0.000 __about__.py:1(<module>)
#        12    0.000    0.000    0.000    0.000 _parser.py:304(checkgroupname)
#        12    0.000    0.000    0.000    0.000 __init__.py:968(acquire)
#        74    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#        68    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:986(create_module)
#         7    0.000    0.000    0.000    0.000 dataclasses.py:489(_field_init)
#         1    0.000    0.000    0.000    0.000 traceback.py:162(_format_final_exc_line)
#         3    0.000    0.000    0.000    0.000 traceback.py:312(_original_line)
#         1    0.000    0.000    0.000    0.000 {method 'settimeout' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 dataclasses.py:428(_fields_in_init_order)
#         9    0.000    0.000    0.000    0.000 enum.py:202(__get__)
#        20    0.000    0.000    0.000    0.000 _parser.py:77(__init__)
#         6    0.000    0.000    0.000    0.000 __init__.py:447(usesTime)
#         1    0.000    0.000    0.000    0.000 ec.py:17(EllipticCurveOID)
#         1    0.000    0.000    0.000    0.000 algorithms.py:90(Blowfish)
#         1    0.000    0.000    0.000    0.000 functools.py:35(update_wrapper)
#         1    0.000    0.000    0.000    0.000 padding.py:32(PSS)
#         1    0.000    0.000    0.000    0.000 ssh.py:802(SSHCertificate)
#        37    0.000    0.000    0.000    0.000 _compiler.py:428(_get_iscased)
#        38    0.000    0.000    0.000    0.000 enum.py:820(<genexpr>)
#         2    0.000    0.000    0.000    0.000 inspect.py:1796(_check_class)
#         1    0.000    0.000    0.000    0.000 __init__.py:1878(LoggerAdapter)
#         1    0.000    0.000    0.000    0.000 cursors.py:17(Cursor)
#         3    0.000    0.000    0.000    0.000 threading.py:124(RLock)
#        12    0.000    0.000    0.000    0.000 __init__.py:975(release)
#        22    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         8    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#        26    0.000    0.000    0.000    0.000 __init__.py:429(<genexpr>)
#         8    0.000    0.000    0.000    0.000 typing.py:1583(__eq__)
#         6    0.000    0.000    0.000    0.000 __init__.py:170(<lambda>)
#        11    0.000    0.000    0.000    0.000 enum.py:828(__members__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1465(_clear_cache)
#         1    0.000    0.000    0.000    0.000 typing.py:1433(__mro_entries__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1117(StreamHandler)
#         1    0.000    0.000    0.000    0.000 ec.py:128(EllipticCurvePublicKey)
#         2    0.000    0.000    0.000    0.000 inspect.py:748(unwrap)
#         5    0.000    0.000    0.000    0.000 err.py:72(_map_error)
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_sha1}
#         2    0.000    0.000    0.000    0.000 typing.py:1196(__getattr__)
#         1    0.000    0.000    0.000    0.000 FIELD_TYPE.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 ec.py:66(EllipticCurvePrivateKey)
#         1    0.000    0.000    0.000    0.000 rsa.py:70(RSAPublicKey)
#         1    0.000    0.000    0.000    0.000 selectors.py:80(BaseSelector)
#         1    0.000    0.000    0.000    0.000 _cipheralgorithm.py:13(CipherAlgorithm)
#         1    0.000    0.000    0.000    0.000 rsa.py:17(RSAPrivateKey)
#        16    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 ed25519.py:60(Ed25519PrivateKey)
#         3    0.000    0.000    0.000    0.000 {method 'co_positions' of 'code' objects}
#        13    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#         2    0.000    0.000    0.000    0.000 {method 'clear' of 'list' objects}
#        14    0.000    0.000    0.000    0.000 enum.py:1692(_simple_enum)
#         1    0.000    0.000    0.000    0.000 six.py:96(__get__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2140(_signature_is_builtin)
#         2    0.000    0.000    0.000    0.000 socket.py:100(_intenum_converter)
#         1    0.000    0.000    0.000    0.000 ssh.py:1114(SSHCertificateBuilder)
#         1    0.000    0.000    0.000    0.000 ed25519.py:14(Ed25519PublicKey)
#         1    0.000    0.000    0.000    0.000 hashes.py:36(HashAlgorithm)
#         2    0.000    0.000    0.000    0.000 __init__.py:443(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1353(Manager)
#         1    0.000    0.000    0.000    0.000 _oid.py:157(ExtendedKeyUsageOID)
#        10    0.000    0.000    0.000    0.000 __future__.py:83(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1867(__init__)
#         1    0.000    0.000    0.000    0.000 six.py:493(Module_six_moves_urllib)
#        31    0.000    0.000    0.000    0.000 typing.py:1264(<genexpr>)
#         1    0.000    0.000    0.000    0.000 dsa.py:33(DSAPrivateKey)
#         1    0.000    0.000    0.000    0.000 CR.py:1(<module>)
#         3    0.000    0.000    0.000    0.000 utils.py:71(__getattr__)
#         6    0.000    0.000    0.000    0.000 threading.py:1483(current_thread)
#        38    0.000    0.000    0.000    0.000 __init__.py:89(<lambda>)
#         2    0.000    0.000    0.000    0.000 _parser.py:893(_parse_flags)
#         6    0.000    0.000    0.000    0.000 __init__.py:129(getLevelName)
#         1    0.000    0.000    0.000    0.000 protocol.py:47(MysqlPacket)
#         1    0.000    0.000    0.000    0.000 traceback.py:374(StackSummary)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:94(__new__)
#         6    0.000    0.000    0.000    0.000 enum.py:117(_iter_bits_lsb)
#         1    0.000    0.000    0.000    0.000 configparser.py:1207(SectionProxy)
#         7    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         2    0.000    0.000    0.000    0.000 dataclasses.py:437(_tuple_str)
#         9    0.000    0.000    0.000    0.000 inspect.py:3066(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1482(Logger)
#         1    0.000    0.000    0.000    0.000 connections.py:1176(MySQLResult)
#        22    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_sha256}
#         4    0.000    0.000    0.000    0.000 dataclasses.py:857(_set_qualname)
#         4    0.000    0.000    0.000    0.000 enum.py:816(__iter__)
#         2    0.000    0.000    0.000    0.000 traceback.py:638(_display_width)
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_sha3_224}
#        12    0.000    0.000    0.000    0.000 __init__.py:831(filter)
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_sha3_384}
#         1    0.000    0.000    0.000    0.000 __init__.py:255(escape)
#         3    0.000    0.000    0.000    0.000 traceback.py:662(indent)
#         4    0.000    0.000    0.000    0.000 utils.py:78(__setattr__)
#        14    0.000    0.000    0.000    0.000 dataclasses.py:683(_is_classvar)
#         1    0.000    0.000    0.000    0.000 traceback.py:679(TracebackException)
#         6    0.000    0.000    0.000    0.000 __init__.py:383(getMessage)
#         1    0.000    0.000    0.000    0.000 dsa.py:85(DSAPublicKey)
#         1    0.000    0.000    0.000    0.000 charset.py:47(by_name)
#         1    0.000    0.000    0.000    0.000 utils.py:14(Prehashed)
#         1    0.000    0.000    0.000    0.000 algorithms.py:26(AES)
#         3    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 <frozen _collections_abc>:341(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_sha512}
#         1    0.000    0.000    0.000    0.000 hashes.py:60(HashContext)
#        14    0.000    0.000    0.000    0.000 dataclasses.py:461(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:919(Handler)
#         1    0.000    0.000    0.000    0.000 string.py:57(Template)
#         1    0.000    0.000    0.000    0.000 __init__.py:1497(__init__)
#         1    0.000    0.000    0.000    0.000 ssh.py:247(_FragList)
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'bytes' objects}
# ...
#         4    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 functools.py:65(wraps)
#        15    0.000    0.000    0.000    0.000 inspect.py:2786(name)
#         1    0.000    0.000    0.000    0.000 hashes.py:163(SHAKE128)
#         1    0.000    0.000    0.000    0.000 _oid.py:44(OCSPExtensionOID)
#         1    0.000    0.000    0.000    0.000 modes.py:112(CBC)
#         1    0.000    0.000    0.000    0.000 six.py:108(MovedModule)
#         1    0.000    0.000    0.000    0.000 algorithms.py:73(TripleDES)
#         1    0.000    0.000    0.000    0.000 algorithms.py:40(AES128)
#         1    0.000    0.000    0.000    0.000 six.py:85(_import_module)
#         4    0.000    0.000    0.000    0.000 enum.py:1411(<lambda>)
#         3    0.000    0.000    0.000    0.000 inspect.py:296(isclass)
#         1    0.000    0.000    0.000    0.000 typing.py:494(__repr__)
#         2    0.000    0.000    0.000    0.000 typing.py:1270(__eq__)
#         3    0.000    0.000    0.000    0.000 inspect.py:372(isfunction)
#         1    0.000    0.000    0.000    0.000 database.py:3(Database)
#         1    0.000    0.000    0.000    0.000 __future__.py:81(_Feature)
#         1    0.000    0.000    0.000    0.000 ssh.py:510(_SSHFormatEd25519)
#         1    0.000    0.000    0.000    0.000 utils.py:66(_ModuleWithDeprecations)
#         1    0.000    0.000    0.000    0.000 ec.py:55(EllipticCurveSignatureAlgorithm)
#         1    0.000    0.000    0.000    0.000 _oid.py:180(CertificatePoliciesOID)
#         1    0.000    0.000    0.000    0.000 algorithms.py:216(SM4)
#         1    0.000    0.000    0.000    0.000 optionfile.py:4(Parser)
#         1    0.000    0.000    0.000    0.000 configparser.py:169(Error)
#         1    0.000    0.000    0.000    0.000 idna.py:154(Codec)
#         2    0.000    0.000    0.000    0.000 {built-in method maketrans}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1014(is_package)
#         1    0.000    0.000    0.000    0.000 inspect.py:304(ismethoddescriptor)
#         8    0.000    0.000    0.000    0.000 dataclasses.py:1142(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:286(LogRecord)
#         1    0.000    0.000    0.000    0.000 __init__.py:1373(disable)
#         1    0.000    0.000    0.000    0.000 __init__.py:2285(NullHandler)
#         5    0.000    0.000    0.000    0.000 __init__.py:1776(getEffectiveLevel)
#         1    0.000    0.000    0.000    0.000 hashes.py:205(BLAKE2b)
#         1    0.000    0.000    0.000    0.000 base.py:46(AEADCipherContext)
#         1    0.000    0.000    0.000    0.000 base.py:63(AEADEncryptionContext)
#         1    0.000    0.000    0.000    0.000 modes.py:43(ModeWithTweak)
#         1    0.000    0.000    0.000    0.000 ec.py:318(ECDSA)
#         3    0.000    0.000    0.000    0.000 ssh.py:453(__init__)
#         1    0.000    0.000    0.000    0.000 algorithms.py:148(IDEA)
#         1    0.000    0.000    0.000    0.000 algorithms.py:171(SEED)
#         1    0.000    0.000    0.000    0.000 six.py:194(find_spec)
#         1    0.000    0.000    0.000    0.000 SERVER_STATUS.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 cursors.py:381(DictCursorMixin)
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'translate' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 <frozen abc>:146(update_abstractmethods)
#         8    0.000    0.000    0.000    0.000 dataclasses.py:432(<genexpr>)
#         1    0.000    0.000    0.000    0.000 typing.py:984(_is_typevar_like)
#         1    0.000    0.000    0.000    0.000 __init__.py:1202(FileHandler)
#         1    0.000    0.000    0.000    0.000 __init__.py:82(DBAPISet)
#         1    0.000    0.000    0.000    0.000 hashes.py:181(SHAKE256)
#         1    0.000    0.000    0.000    0.000 exceptions.py:17(UnsupportedAlgorithm)
#         1    0.000    0.000    0.000    0.000 _oid.py:171(AuthorityInformationAccessOID)
#         1    0.000    0.000    0.000    0.000 modes.py:126(XTS)
#         1    0.000    0.000    0.000    0.000 ssl.py:170(_TLSContentType)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 _parser.py:312(_class_escape)
#         2    0.000    0.000    0.000    0.000 contextlib.py:446(__exit__)
#         1    0.000    0.000    0.000    0.000 inspect.py:518(isbuiltin)
#         1    0.000    0.000    0.000    0.000 __init__.py:727(BufferingFormatter)
#         1    0.000    0.000    0.000    0.000 traceback.py:656(_ExceptionPrintContext)
#         1    0.000    0.000    0.000    0.000 connections.py:1402(LoadLocalFile)
#         1    0.000    0.000    0.000    0.000 base.py:54(AEADDecryptionContext)
#         1    0.000    0.000    0.000    0.000 modes.py:52(ModeWithNonce)
#         1    0.000    0.000    0.000    0.000 modes.py:61(ModeWithAuthenticationTag)
#         1    0.000    0.000    0.000    0.000 modes.py:161(OFB)
#         1    0.000    0.000    0.000    0.000 six.py:129(_LazyModule)
#         1    0.000    0.000    0.000    0.000 six.py:144(MovedAttribute)
#         1    0.000    0.000    0.000    0.000 padding.py:89(MGF)
#         1    0.000    0.000    0.000    0.000 base.py:264(_AEADEncryptionContext)
#         1    0.000    0.000    0.000    0.000 algorithms.py:50(AES256)
#         1    0.000    0.000    0.000    0.000 six.py:178(__init__)
#         1    0.000    0.000    0.000    0.000 charset.py:34(Charsets)
#         1    0.000    0.000    0.000    0.000 configparser.py:298(ParsingError)
#         1    0.000    0.000    0.000    0.000 configparser.py:332(Interpolation)
#         1    0.000    0.000    0.000    0.000 configparser.py:182(NoSectionError)
#         3    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 __init__.py:1369(disable)
#         1    0.000    0.000    0.000    0.000 _serialization.py:63(BestAvailableEncryption)
#         1    0.000    0.000    0.000    0.000 modes.py:175(CFB)
#         1    0.000    0.000    0.000    0.000 charset.py:16(encoding)
#         1    0.000    0.000    0.000    0.000 modes.py:203(CTR)
#         1    0.000    0.000    0.000    0.000 six.py:91(_LazyDescr)
#         1    0.000    0.000    0.000    0.000 charset.py:35(__init__)
#         1    0.000    0.000    0.000    0.000 numbers.py:37(Number)
#         1    0.000    0.000    0.000    0.000 idna.py:261(IncrementalDecoder)
#         4    0.000    0.000    0.000    0.000 {built-in method _sre.ascii_iscased}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         7    0.000    0.000    0.000    0.000 inspect.py:2790(default)
#         2    0.000    0.000    0.000    0.000 contextlib.py:443(__enter__)
#         1    0.000    0.000    0.000    0.000 traceback.py:90(_Sentinel)
#         1    0.000    0.000    0.000    0.000 __init__.py:1861(RootLogger)
#         1    0.000    0.000    0.000    0.000 _serialization.py:154(_KeySerializationEncryption)
#         1    0.000    0.000    0.000    0.000 exceptions.py:43(InternalError)
#         1    0.000    0.000    0.000    0.000 _oid.py:176(SubjectInformationAccessOID)
#         1    0.000    0.000    0.000    0.000 six.py:340(Module_six_moves_urllib_parse)
#         1    0.000    0.000    0.000    0.000 <string>:1(__create_fn__)
#         1    0.000    0.000    0.000    0.000 idna.py:226(IncrementalEncoder)
#         4    0.000    0.000    0.000    0.000 {built-in method _sre.ascii_tolower}
#         3    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 typing.py:295(_check_generic)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:433(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1033(setFormatter)
#         1    0.000    0.000    0.000    0.000 __init__.py:1311(PlaceHolder)
#         1    0.000    0.000    0.000    0.000 err.py:6(MySQLError)
#         1    0.000    0.000    0.000    0.000 socket.py:212(_GiveupOnSendfile)
#         1    0.000    0.000    0.000    0.000 utils.py:59(_DeprecatedValue)
#         1    0.000    0.000    0.000    0.000 hashes.py:151(SHA3_384)
#         1    0.000    0.000    0.000    0.000 hashes.py:199(MD5)
#         1    0.000    0.000    0.000    0.000 modes.py:155(ECB)
#         1    0.000    0.000    0.000    0.000 configparser.py:191(DuplicateSectionError)
#         1    0.000    0.000    0.000    0.000 configparser.py:255(InterpolationError)
#         1    0.000    0.000    0.000    0.000 protocol.py:286(OKPacketWrapper)
#         1    0.000    0.000    0.000    0.000 idna.py:303(StreamReader)
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'tuple' objects}
#         2    0.000    0.000    0.000    0.000 {method '__init_subclass__' of 'object' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 __init__.py:769(Filter)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:372(__init__)
#         1    0.000    0.000    0.000    0.000 traceback.py:673(<lambda>)
#         1    0.000    0.000    0.000    0.000 err.py:10(Warning)
#         1    0.000    0.000    0.000    0.000 _serialization.py:59(KeySerializationEncryption)
#         1    0.000    0.000    0.000    0.000 _serialization.py:71(NoEncryption)
#         1    0.000    0.000    0.000    0.000 utils.py:16(CryptographyDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 hashes.py:103(SHA512_224)
#         1    0.000    0.000    0.000    0.000 hashes.py:97(SHA1)
#         1    0.000    0.000    0.000    0.000 hashes.py:115(SHA224)
#         1    0.000    0.000    0.000    0.000 hashes.py:121(SHA256)
#         1    0.000    0.000    0.000    0.000 hashes.py:133(SHA512)
#         1    0.000    0.000    0.000    0.000 hashes.py:139(SHA3_224)
#         1    0.000    0.000    0.000    0.000 hashes.py:145(SHA3_256)
#         1    0.000    0.000    0.000    0.000 hashes.py:91(ExtendableOutputFunction)
#         1    0.000    0.000    0.000    0.000 ec.py:198(SECT571R1)
#         1    0.000    0.000    0.000    0.000 ec.py:208(SECT283R1)
#         1    0.000    0.000    0.000    0.000 ec.py:213(SECT233R1)
#         1    0.000    0.000    0.000    0.000 ec.py:238(SECT233K1)
#         1    0.000    0.000    0.000    0.000 ec.py:283(BrainpoolP384R1)
#         1    0.000    0.000    0.000    0.000 exceptions.py:51(InvalidKey)
#         1    0.000    0.000    0.000    0.000 padding.py:16(PKCS1v15)
#         1    0.000    0.000    0.000    0.000 base.py:249(_AEADDecryptionContext)
#         1    0.000    0.000    0.000    0.000 padding.py:20(_MaxLength)
#         1    0.000    0.000    0.000    0.000 padding.py:24(_Auto)
#         1    0.000    0.000    0.000    0.000 six.py:245(_MovedItems)
#         1    0.000    0.000    0.000    0.000 six.py:382(Module_six_moves_urllib_error)
#         1    0.000    0.000    0.000    0.000 configparser.py:244(NoOptionError)
#         1    0.000    0.000    0.000    0.000 configparser.py:217(DuplicateOptionError)
#         1    0.000    0.000    0.000    0.000 configparser.py:312(MissingSectionHeaderError)
#         1    0.000    0.000    0.000    0.000 configparser.py:285(InterpolationDepthError)
#         1    0.000    0.000    0.000    0.000 configparser.py:265(InterpolationMissingOptionError)
#         1    0.000    0.000    0.000    0.000 cursors.py:405(DictCursor)
#         1    0.000    0.000    0.000    0.000 protocol.py:314(EOFPacketWrapper)
#         1    0.000    0.000    0.000    0.000 protocol.py:337(LoadLocalPacketWrapper)
#         1    0.000    0.000    0.000    0.000 getpass.py:26(GetPassWarning)
#         1    0.000    0.000    0.000    0.000 idna.py:300(StreamWriter)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 dataclasses.py:879(_hash_set_none)
#         2    0.000    0.000    0.000    0.000 inspect.py:3079(parameters)
#         2    0.000    0.000    0.000    0.000 inspect.py:3083(return_annotation)
#         2    0.000    0.000    0.000    0.000 __init__.py:254(_register_at_fork_reinit_lock)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 err.py:15(Error)
#         1    0.000    0.000    0.000    0.000 err.py:20(InterfaceError)
#         1    0.000    0.000    0.000    0.000 err.py:36(OperationalError)
#         1    0.000    0.000    0.000    0.000 err.py:44(IntegrityError)
#         1    0.000    0.000    0.000    0.000 err.py:50(InternalError)
#         1    0.000    0.000    0.000    0.000 err.py:56(ProgrammingError)
#         1    0.000    0.000    0.000    0.000 err.py:62(NotSupportedError)
#         1    0.000    0.000    0.000    0.000 utils.py:55(InterfaceNotImplemented)
#         1    0.000    0.000    0.000    0.000 hashes.py:109(SHA512_256)
#         1    0.000    0.000    0.000    0.000 hashes.py:127(SHA384)
#         1    0.000    0.000    0.000    0.000 hashes.py:157(SHA3_512)
#         1    0.000    0.000    0.000    0.000 hashes.py:239(SM3)
#         1    0.000    0.000    0.000    0.000 ec.py:203(SECT409R1)
#         1    0.000    0.000    0.000    0.000 ec.py:218(SECT163R2)
#         1    0.000    0.000    0.000    0.000 ec.py:223(SECT571K1)
#         1    0.000    0.000    0.000    0.000 ec.py:228(SECT409K1)
#         1    0.000    0.000    0.000    0.000 ec.py:233(SECT283K1)
#         1    0.000    0.000    0.000    0.000 ec.py:243(SECT163K1)
#         1    0.000    0.000    0.000    0.000 ec.py:248(SECP521R1)
#         1    0.000    0.000    0.000    0.000 ec.py:253(SECP384R1)
#         1    0.000    0.000    0.000    0.000 ec.py:258(SECP256R1)
#         1    0.000    0.000    0.000    0.000 ec.py:263(SECP256K1)
#         1    0.000    0.000    0.000    0.000 ec.py:268(SECP224R1)
#         1    0.000    0.000    0.000    0.000 ec.py:278(BrainpoolP256R1)
#         1    0.000    0.000    0.000    0.000 ec.py:288(BrainpoolP512R1)
#         1    0.000    0.000    0.000    0.000 exceptions.py:23(AlreadyFinalized)
#         1    0.000    0.000    0.000    0.000 exceptions.py:27(AlreadyUpdated)
#         1    0.000    0.000    0.000    0.000 exceptions.py:35(InvalidTag)
#         1    0.000    0.000    0.000    0.000 ec.py:349(ECDH)
#         1    0.000    0.000    0.000    0.000 six.py:402(Module_six_moves_urllib_request)
#         1    0.000    0.000    0.000    0.000 six.py:454(Module_six_moves_urllib_response)
#         1    0.000    0.000    0.000    0.000 cursors.py:530(SSDictCursor)
#         1    0.000    0.000    0.000    0.000 configparser.py:277(InterpolationSyntaxError)
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 err.py:25(DatabaseError)
#         1    0.000    0.000    0.000    0.000 err.py:30(DataError)
#         1    0.000    0.000    0.000    0.000 ec.py:273(SECP192R1)
#         1    0.000    0.000    0.000    0.000 exceptions.py:31(NotYetFinalized)
#         1    0.000    0.000    0.000    0.000 exceptions.py:39(InvalidSignature)
#         1    0.000    0.000    0.000    0.000 padding.py:28(_DigestLength)
#         1    0.000    0.000    0.000    0.000 six.py:475(Module_six_moves_urllib_robotparser)
# 2024-12-02 07:32:44,795 - DEBUG - This is a debug message
# 2024-12-02 07:32:44,795 - INFO - This is an info message
# 2024-12-02 07:32:44,795 - WARNING - This is a warning message
# 2024-12-02 07:32:44,795 - ERROR - This is an error message
# 2024-12-02 07:32:44,795 - CRITICAL - This is a critical message
# 2024-12-02 07:32:44,800 - ERROR - Error: division by zero

# %% [markdown]
# ### Use Built-in Libraries

# %%
import math
from collections import deque, Counter

# Custom implementation
def custom_sqrt(x):
    return x ** 0.5

# Optimized using math.sqrt()
def optimized_sqrt(x):
    return math.sqrt(x)

# Custom factorial 
def custom_factorial(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

# Optimized using math.factorial()
print(math.factorial(10)) 


## collection


# Using deque for fast append and pop operations
queue = deque([1, 2, 3])
queue.append(4)      # O(1)
queue.popleft()      # O(1)
print(queue)         # Output: deque([2, 3, 4])

# Using Counter for counting elements
words = ["apple", "banana", "apple", "orange", "banana", "apple"]
word_count = Counter(words)
print(word_count)

# %% [markdown]
# #### Use functools.lru_cache for Memoization
# - LRU (least recently used)

# %%
from functools import lru_cache

@lru_cache(maxsize=None)  # Cache all results
def fibonacci(n):
    if n < 2:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)

print(fibonacci(50))

# %% [markdown]
# ### Homework
# - Explore ``itertools `` for memory efficient iteration tasks

# %% [markdown]
# #### Profiling within the Script

# %%
import cProfile

def slow_function():
    total = 0
    for i in range(1000000):
        total += i
    return total

def fast_function():
    return sum(range(1000000))

# cProfile.run('slow_function()')  
cProfile.run('fast_function()')
# Out:
#          6 function calls (5 primitive calls) in 0.052 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 1072814776.py:9(fast_function)
#         1    0.000    0.000    0.052    0.052 <string>:1(<module>)
#       2/1    0.000    0.000    0.052    0.052 {built-in method builtins.exec}
#         1    0.052    0.052    0.052    0.052 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ###  HomeWork
# - Use Line Profiler for line-by-line profiling

# %% [markdown]
# ## Reference Counting
# - In Python, reference counting is used to track how many references exist for each object in memory
# - The reference count is managed by by Python's memory management system.
# - ``sys.getrefcount()`` to count the reference of an object

# %%
import sys

def reference_count_example():
    a = []  
    print(f"Reference count for 'a': {sys.getrefcount(a)}")

    b = a  # 'b' references the same list object
    print(f"Reference count for 'a' after assigning b = a: {sys.getrefcount(a)}")
    print(f"Reference count for 'b': {sys.getrefcount(b)}")

    c = b  # 'c' references the same list object
    print(f"Reference count for 'a' after assigning c = b: {sys.getrefcount(a)}")
    print(f"Reference count for 'b' after assigning c = b: {sys.getrefcount(b)}")
    print(f"Reference count for 'c': {sys.getrefcount(c)}")

    # Now, deleting the references
    del b
    print(f"Reference count for 'a' after deleting 'b': {sys.getrefcount(a)}")

    del c
    print(f"Reference count for 'a' after deleting 'c': {sys.getrefcount(a)}")

reference_count_example()
# Out:
# Reference count for 'a': 2

# %% [markdown]
# ## Global Interpreter Lock (GIL)

# %% [markdown]
# ### GIL limits multi-threaded performance in CPU-bound tasks

# %%
import threading
import time

def sum_of_squares(n):
    total = sum(i * i for i in range(n))
    print(f"Sum of squares up to {n}: {total}")

# Measure time for multi-threaded execution
def threaded_execution():
    threads = []
    start_time = time.time()
    # Create threads
    for _ in range(2):
        t = threading.Thread(target=sum_of_squares, args=(10_000_000,))
        threads.append(t)
        t.start()
    
    # Wait for all threads to complete
    for t in threads:
        t.join()

    print(f"Time taken (threads): {time.time() - start_time:.2f} seconds")

# Measure time for single-threaded execution
def single_threaded_execution():
    start_time = time.time()
    sum_of_squares(10_000_000)
    sum_of_squares(10_000_000)
    print(f"Time taken (single thread): {time.time() - start_time:.2f} seconds")

print("Running with Threads:")
threaded_execution()
print("\nRunning Single-Threaded:")
single_threaded_execution()
# Out:
# Running with Threads:
# Sum of squares up to 10000000: 333333283333335000000
# Sum of squares up to 10000000: 333333283333335000000
# Time taken (threads): 2.16 seconds
#
# Running Single-Threaded:
# Sum of squares up to 10000000: 333333283333335000000
# Sum of squares up to 10000000: 333333283333335000000
# Time taken (single thread): 1.93 seconds

# %% [markdown]
# # Best selling mobile brands

# %%
import pandas as pd
data = pd.read_csv('data/top 120 best-selling mobile phones.csv')
data.head()
# Out:
#    Rank Manufacturer                Model  Form Factor  Smartphone?  Year  \
# 0     1        Nokia                 1100          Bar        False  2003
# 1     2        Nokia                 1110          Bar        False  2005
# 2     3        Apple    iPhone 6 & 6 Plus  Touchscreen         True  2014
# 3     4        Nokia           105 Series          Bar        False  2013
# 4     5        Apple  iPhone 6S & 6S Plus  Touchscreen         True  2015
#
#    Units Sold (million )
# 0                  250.0
# 1                  247.5
# 2                  222.4
# 3                  200.0
# 4                  174.1

# %% [markdown]
# # Data cleaning

# %%
data.dropna(inplace=True)
data.rename(columns={'Smartphone?':'smartphone','Units Sold (million )':'unit_sold','Form Factor':'form_factor'},inplace=True)
data.head()
# Out:
#    Rank Manufacturer                Model  form_factor  smartphone  Year  \
# 0     1        Nokia                 1100          Bar       False  2003
# 1     2        Nokia                 1110          Bar       False  2005
# 2     3        Apple    iPhone 6 & 6 Plus  Touchscreen        True  2014
# 3     4        Nokia           105 Series          Bar       False  2013
# 4     5        Apple  iPhone 6S & 6S Plus  Touchscreen        True  2015
#
#    unit_sold
# 0      250.0
# 1      247.5
# 2      222.4
# 3      200.0
# 4      174.1

# %% [markdown]
# # Insert data into database

# %%
# create table
from db.database import Database


db = Database('localhost','student','xyz344324wW','students',3307)

# user 

create_table_query = """CREATE TABLE IF NOT EXISTS mobiles (
    id int(11) NOT NULL AUTO_INCREMENT,
    rank int(11) NOT NULL,
    manufacturer varchar(255)  NOT NULL,
    model varchar(255)  NOT NULL,
    form_factor varchar(255)  NOT NULL,
    smartphone boolean  DEFAULT true,
    year int(4) not null,
        unit_sold int(11) not null,
        PRIMARY KEY (id)
) 
AUTO_INCREMENT=1"""
db.execute_query(create_table_query)

def insert_data(mobile):
    insert_query = f"""INSERT INTO mobiles(rank,manufacturer,model,form_factor,smartphone,year,unit_sold) 
    VALUES({mobile['Rank']},'{mobile['Manufacturer']}','{mobile['Model']}',
    '{mobile['form_factor']}',{mobile['smartphone']},{mobile['Year']},{mobile['unit_sold']})"""
    db.execute_query(insert_query)



for _,mobile in data.iterrows():
    insert_data(mobile)
# Out:
# [{'id': 120, 'rank': 120, 'manufacturer': 'Palm', 'model': 'Centro', 'form_factor': 'Keyboard bar', 'smartphone': 1, 'year': 2007, 'unit_sold': 2}, {'id': 119, 'rank': 119, 'manufacturer': 'Google', 'model': 'Pixel & Pixel XL', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2016, 'unit_sold': 2}, {'id': 118, 'rank': 118, 'manufacturer': 'Samsung', 'model': 'Samsung Galaxy A15 4G', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2023, 'unit_sold': 2}, {'id': 117, 'rank': 117, 'manufacturer': 'Samsung', 'model': 'Samsung Galaxy S24', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2024, 'unit_sold': 2}, {'id': 116, 'rank': 116, 'manufacturer': 'Samsung', 'model': 'Samsung Galaxy A55', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2024, 'unit_sold': 3}, {'id': 115, 'rank': 115, 'manufacturer': 'LeTV', 'model': 'LeEco Le 1s', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2016, 'unit_sold': 3}, {'id': 114, 'rank': 114, 'manufacturer': 'LG', 'model': 'G2', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2013, 'unit_sold': 3}, {'id': 113, 'rank': 113, 'manufacturer': 'Nokia', 'model': 'N-Gage', 'form_factor': 'Taco', 'smartphone': 1, 'year': 2003, 'unit_sold': 3}, {'id': 112, 'rank': 112, 'manufacturer': 'Samsung', 'model': 'Galaxy A30s', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2019, 'unit_sold': 3}, {'id': 111, 'rank': 111, 'manufacturer': 'Samsung', 'model': 'Samsung Galaxy S23 FE', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2023, 'unit_sold': 4}, {'id': 110, 'rank': 110, 'manufacturer': 'Samsung', 'model': 'Galaxy A10s', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2019, 'unit_sold': 4}, {'id': 109, 'rank': 109, 'manufacturer': 'Samsung', 'model': 'Samsung Galaxy 414 4G', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2023, 'unit_sold': 4}, {'id': 108, 'rank': 108, 'manufacturer': 'Samsung', 'model': 'Samsung Galaxy J9+', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2014, 'unit_sold': 5}, {'id': 107, 'rank': 107, 'manufacturer': 'Samsung', 'model': 'Samsung Galaxy S24 Ultra', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2024, 'unit_sold': 5}, {'id': 106, 'rank': 106, 'manufacturer': 'Samsung', 'model': 'Galaxy J6+', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2018, 'unit_sold': 5}, {'id': 105, 'rank': 105, 'manufacturer': 'LG', 'model': 'Viewty(KU990)', 'form_factor': 'Bar', 'smartphone': 0, 'year': 2007, 'unit_sold': 5}, {'id': 104, 'rank': 104, 'manufacturer': 'Apple', 'model': 'iPhone', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2007, 'unit_sold': 6}, {'id': 103, 'rank': 103, 'manufacturer': 'Samsung', 'model': 'Galaxy J4+', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2018, 'unit_sold': 6}, {'id': 102, 'rank': 102, 'manufacturer': 'Xiaomi', 'model': 'Redmi 8', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2019, 'unit_sold': 7}, {'id': 101, 'rank': 101, 'manufacturer': 'Oppo', 'model': 'F1 Plus', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2016, 'unit_sold': 7}, {'id': 100, 'rank': 100, 'manufacturer': 'Xiaomi', 'model': 'Redmi 8A', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2019, 'unit_sold': 7}, {'id': 99, 'rank': 99, 'manufacturer': 'Samsung', 'model': 'Galaxy A30', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2019, 'unit_sold': 9}, {'id': 98, 'rank': 98, 'manufacturer': 'Samsung', 'model': 'Galaxy Note 9', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2018, 'unit_sold': 10}, {'id': 97, 'rank': 97, 'manufacturer': 'Oppo', 'model': 'A5', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2019, 'unit_sold': 10}, {'id': 96, 'rank': 96, 'manufacturer': 'Samsung', 'model': 'Galaxy S20 FE', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2020, 'unit_sold': 10}, {'id': 95, 'rank': 95, 'manufacturer': 'Xiaomi', 'model': 'Redmi 6A', 'form_factor': 'Touchscreen', 'smartphone': 1, 'year': 2019, 'unit_sold': 10}, {'id': 94, 'rank': 9 ...

# %%
select_query = f"SELECT manufacturer, sum(unit_sold) as total_sell  from mobiles GROUP BY manufacturer order by total_sell DESC limit 10"
mobiles = db.execute_query(select_query)
for mobile in mobiles:
    print(mobile)
# Out:
# {'manufacturer': 'Nokia', 'total_sell': Decimal('2375')}
# {'manufacturer': 'Apple', 'total_sell': Decimal('1669')}
# {'manufacturer': 'Samsung', 'total_sell': Decimal('993')}
# {'manufacturer': 'Motorola', 'total_sell': Decimal('323')}
# {'manufacturer': 'Huawei', 'total_sell': Decimal('114')}
# {'manufacturer': 'Xiaomi', 'total_sell': Decimal('99')}
# {'manufacturer': 'LG', 'total_sell': Decimal('92')}
# {'manufacturer': 'Sony Ericsson', 'total_sell': Decimal('45')}
# {'manufacturer': 'Oppo', 'total_sell': Decimal('17')}
# {'manufacturer': 'HTC', 'total_sell': Decimal('16')}
